# %%
import pandas as pd
import numpy as np
import re
from pymystem3 import Mystem
from tika import parser

# %%
raw = parser.from_file('homework-theory-06-ensembles.pdf')
print(raw['content'])
# Out:
# 2020-05-26 20:39:06,064 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# Машинное обучение, ФКН ВШЭ
#
# Домашнее задание №6
#
# Задача 1. Пусть x ∈ Rd, и значение каждого признака на объекте x независимо ге-
# нерируется из равномерного распределения: xi ∼ U [0, 1], i = 1, . . . , d. Будем считать,
# что объекты в выборке независимы, а E[y|x] = xTx. Найдите смещение константного
# алгоритма: µ(X)(x) = C = const.
#
# Задача 2. Предположим, что объекты описываются единственным категориаль-
#
# ным признаком, принимающим значения x = 1, . . . , K с равной вероятностью, объ-
# екты независимы. Для каждой категории x определено истинное целевое значение
#
# fx, а наблюдаемое целевое значение для объекта x определяется как y = fx + ε,
# ε ∼ N (0, σ2). Алгоритм обучения µ(X) запоминает среднее значение для каждой ка-
# тегории следующим образом: f̂x =
#
# 1
#
# ℓ
#
# ∑
# ℓ
#
# i=1
# [xi = x] yi, а затем для объекта x выдаёт
#
# ...
